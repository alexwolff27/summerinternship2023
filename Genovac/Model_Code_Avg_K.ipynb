# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

from google.colab import drive
drive.mount('/content/drive')

#Importing the Excel File
dataset_1 = '/content/drive/MyDrive/Kinetics/Processed Rage Chimeric_21Jun23.csv'
dataset = pd.read_csv(dataset_1)

display(dataset)

#Creating the Table for the Averages
avg = pd.pivot_table(data=dataset, index='Name', aggfunc = 'mean')
avg.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#         Name      k-on      k-off           K-D
# 0    365-1.2  1590000.0  0.001060  6.680000e-10
# 1    382-1.2  1860000.0  0.000604  3.250000e-10
# 2    383-1.2  1640000.0  0.000685  4.160000e-10
# 3    395-1.3  5580000.0  0.000581  1.040000e-10
# 4    396-1.2   841000.0  0.000663  7.880000e-10
# ..       ...        ...       ...           ...
# 116  398-1.3  2060000.0  0.002890  1.400000e-09
# 117  399-1.2   242000.0  0.000450  1.860000e-09
# 118  399-1.2   331000.0  0.000499  1.510000e-09
# 119  400-1.2  3220000.0  0.000989  3.070000e-10
# 120  400-1.2  3280000.0  0.001570  4.790000e-10
#
# [121 rows x 4 columns]
#                   K-D     k-off         k-on
# Name
# 351-1.2  1.025333e-09  0.002990  2.946667e+06
# 352-2.2  7.530000e-10  0.003563  4.996667e+06
# 353-1.2  1.718333e-11  0.000067  4.333333e+06
# ...

# %%
#Generating the Graphs
dict_e = {0: 'K_D Avg', 1: 'k_off Avg', 2:'k_on Avg'}

fig, axs = plt.subplots(len(avg.columns), figsize=(15,10))
fig.subplots_adjust(hspace=0.8)

for i, j in dict_e.items():
  axs[i].bar(avg.index, avg.iloc[:, i])
  axs[i].title.set_text(j)
  axs[i].set_ylabel('Value')
  axs[i].set_xlabel('Clone ID')
  axs[i].tick_params(axis='x', labelrotation=60)

plt.show()
